# %% [markdown]
# # Clustering publishers with cosine similarity

# %%
from pyspark.sql.types import *
import pyspark.sql.functions as F
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
import google.datalab.storage as storage
import pandas as pd
from io import BytesIO
from google.datalab import Context

# %%
# hide warning message
import warnings
warnings.filterwarnings('ignore')

# %%
my_bucket = "gs://summer-heaven-223608-bucket/data/"

# %%
my_bucket = storage.Bucket('summer-heaven-223608-bucket/data')

docu_meta = my_bucket.object('documents_meta.csv')
uri5 = docu_meta.uri
# %gcs read --object $uri5 --variable c_docu_meta
docu_meta = pd.read_csv(BytesIO(c_docu_meta))

events = my_bucket.object('events.csv')
uri7 = events.uri
# %gcs read --object $uri7 --variable c_events
events = pd.read_csv(BytesIO(c_events))

# %%
documents_categories = my_bucket.object('documents_categories.csv')
uri8 = documents_categories.uri
# %gcs read --object $uri8 --variable c_documents_categories
docu_cate = pd.read_csv(BytesIO(c_documents_categories))

# %%
docu_meta.head()
# Out:
#    document_id  source_id  publisher_id         publish_time
# 0      1595802        1.0         603.0  2016-06-05 00:00:00
# 1      1524246        1.0         603.0  2016-05-26 11:00:00
# 2      1617787        1.0         603.0  2016-05-27 00:00:00
# 3      1615583        1.0         603.0  2016-06-07 00:00:00
# 4      1615460        1.0         603.0  2016-06-20 00:00:00

# %%
events.head()
# Out:
#    display_id            uuid  document_id  timestamp platform geo_location
# 0           1  cb8c55702adb93       379743         61        3    US>SC>519
# 1           2  79a85fa78311b9      1794259         81        2    US>CA>807
# 2           3  822932ce3d8757      1179111        182        2    US>MI>505
# 3           4  85281d0a49f7ac      1777797        234        2    US>WV>564
# 4           5  8d0daef4bf5b56       252458        338        2        SG>00

# %%
docu_cate.head()
# Out:
#    document_id  category_id  confidence_level
# 0      1595802         1611              0.92
# 1      1595802         1610              0.07
# 2      1524246         1807              0.92
# 3      1524246         1608              0.07
# 4      1617787         1807              0.92

# %%
# events와 docu_meta를 inner_join

view_page = pd.merge(events, docu_meta, how = "inner", on = "document_id")

# %%
view_page.shape
# Out:
# (23120126, 9)

# %%
view_page.head()
# Out:
#    display_id            uuid  document_id  timestamp platform geo_location  \
# 0           1  cb8c55702adb93       379743         61        3    US>SC>519
# 1     1239772  a2eb3a4e0a4c08       379743   74476960        1        CA>BC
# 2     1306670  c9d0cf076200f3       379743   78297892        2           US
# 3     2357895  6e0aabe592ba61       379743  148985378        2           US
# 4     2785946  1eb4bef36f8623       379743  177159039        1    US>RI>521
#
#    source_id  publisher_id publish_time
# 0     6482.0          24.0          NaN
# 1     6482.0          24.0          NaN
# 2     6482.0          24.0          NaN
# 3     6482.0          24.0          NaN
# 4     6482.0          24.0          NaN

# %%
# view_page와 documents_categories를 inner_join

view_page_conf = pd.merge(view_page, docu_cate, how = "inner", on = "document_id")

# %%
view_page_conf.head()
# Out:
#    display_id            uuid  document_id  timestamp platform geo_location  \
# 0           1  cb8c55702adb93       379743         61        3    US>SC>519
# 1           1  cb8c55702adb93       379743         61        3    US>SC>519
# 2     1239772  a2eb3a4e0a4c08       379743   74476960        1        CA>BC
# 3     1239772  a2eb3a4e0a4c08       379743   74476960        1        CA>BC
# 4     1306670  c9d0cf076200f3       379743   78297892        2           US
#
#    source_id  publisher_id publish_time  category_id  confidence_level
# 0     6482.0          24.0          NaN         1203          0.345952
# 1     6482.0          24.0          NaN         1702          0.026322
# 2     6482.0          24.0          NaN         1203          0.345952
# 3     6482.0          24.0          NaN         1702          0.026322
# 4     6482.0          24.0          NaN         1203          0.345952

# %%
view_page_conf.shape
# Out:
# (43828357, 11)

# %%
del_cols = ['display_id', 'uuid', 'document_id', 'timestamp', 'platform', 'geo_location', 'source_id', 'publish_time']
view_page_conf = view_page_conf.drop(del_cols, axis = 1)

# %%
view_page_conf.head()
# Out:
#    publisher_id  category_id  confidence_level
# 0          24.0         1203          0.345952
# 1          24.0         1702          0.026322
# 2          24.0         1203          0.345952
# 3          24.0         1702          0.026322
# 4          24.0         1203          0.345952

# %%
view_page_conf.shape
# Out:
# (43828357, 3)

# %%
view_page_conf['category_id'].nunique()
# Out:
# 90

# %%
import numpy as np

# %%
# 행을 publisher_id, 열을 category_id, 값을 confidence_level의 sum으로 하는 pivot table 생성

view_pivot = pd.pivot_table(view_page_conf, 
                            values = "confidence_level", 
                            index = 'publisher_id', 
                            columns = 'category_id',
                            aggfunc = np.sum)

# %%
# NaN값을 0으로 채움

view_pivot = view_pivot.fillna(0)
view_pivot.head()
# Out:
# category_id        1000         1100       1202        1203       1204  \
# publisher_id
# 2.0            0.000000     9.267442   0.952714    0.000000    0.00000
# 3.0           77.208282  1286.895133   3.040000  256.851352   61.71000
# 7.0            0.000000    74.080000   2.507000   49.655835    3.74000
# 9.0            4.639350  2039.959758  24.039716  520.571316  246.33925
# 10.0           8.680000   955.254396   0.000000    0.168587    0.00000
#
# category_id          1205       1206        1207       1208        1209  \
# publisher_id
# 2.0              4.842871   0.000000    2.760000   3.680000    0.990000
# 3.0           2060.901529  10.010000  226.193974   0.140000  817.449758
# 7.0             93.343045   3.551000    6.780000   9.050000   57.333796
# 9.0           2254.028291  34.759792  136.812663  28.985821  317.241752
# 10.0             0.000000   0.000000    0.000000   0.000000    0.000000
#
# category_id      ...              1912        1913       1914       1915  \
# publisher_id     ...
# 2.0              ...          0.000000    0.000000   0.000000   0.000000
# 3.0              ...       1847.671410   56.464953  24.531165   1.840000
# 7.0              ...          0.000000    0.000000   0.000000   0.000000
# 9.0              ...       1073.647467  153.702126  12.617994   5.203346
# 10.0             ...          0.140000  218.788042   0.000000  28.139334
#
# category_id         2002        2003         2004   2005        2006  \
# publisher_id
# 2.0             1.910000    1.840000     4.573072   0.00    0.000000
# 3.0           139.320000  859.949061  7213.722404  54.05  517.089837
# 7.0             3.450000    4.450000    33.320000   0.21    0.000000
# 9.0             8.232909  205.615276  4399.666920   2.05   27.795822
# 10.0            0.000000    0.000000     0.000000   0.00    0.350000
#
# category_id          2100
# publisher_id
# 2.0              0.000000
# 3.0           1700.355983
# 7.0             23.720000
# 9.0           1258.422320
# 10.0             0.210000
#
# [5 rows x 90 columns]
